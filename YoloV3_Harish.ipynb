# %% [markdown]
# <a href="https://colab.research.google.com/github/HarishSingh1981/YoloV3_Custom/blob/main/YoloV3_Harish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/HarishSingh1981/YoloV3_Custom.git
# !cd YoloV3_Custom
# !git pull
# !cd ..
# Out:
# Cloning into 'YoloV3_Custom'...
# remote: Enumerating objects: 7315, done.
# remote: Counting objects: 100% (135/135), done.
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 7315 (delta 13), reused 34 (delta 8), pack-reused 7180
# Receiving objects: 100% (7315/7315), 255.65 MiB | 68.89 MiB/s, done.
# Resolving deltas: 100% (19/19), done.
# fatal: not a git repository (or any of the parent directories): .git

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.13.1+cu116 _CudaDeviceProperties(name='NVIDIA A100-SXM4-40GB', major=8, minor=0, total_memory=40513MB, multi_processor_count=108)

# %%
ls
# Out:
# gdrive/  sample_data/  YoloV3_Custom/

# %%
cd YoloV3_Custom/
# Out:
# /content/YoloV3_Custom

# %%
# !ls
# Out:
#  cfg	     output	    results.png  'ubdivisions=1'
#  data	     __pycache__    test.py	  utils
#  detect.py   README.md	    ting	  vim.exe.stackdump
#  models.py   results.json   train.py	  weights

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# Out:
# Namespace(epochs=3, batch_size=3, accumulate=4, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', multi_scale=False, img_size=[512], rect=False, resume=False, nosave=True, notest=False, evolve=False, bucket='', cache_images=True, weights='weights/yolov3-spp-ultralytics.pt', name='', device='', adam=False, single_cls=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15101MB)
#
# 2023-03-30 08:22:53.231856: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --nosave
# Out:
# Namespace(epochs=300, batch_size=10, accumulate=4, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', multi_scale=False, img_size=[512], rect=False, resume=False, nosave=True, notest=False, evolve=False, bucket='', cache_images=True, weights='weights/yolov3-spp-ultralytics.pt', name='', device='', adam=False, single_cls=False)
# Using CUDA device0 _CudaDeviceProperties(name='NVIDIA A100-SXM4-40GB', total_memory=40513MB)
#
# 2023-03-30 16:16:35.716450: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# # New Section

# %%
# !python detect.py --source=/content/gdrive/MyDrive/public/youtube_video --conf-thres 0.1 --output youTube_out
# Out:
# Namespace(cfg='cfg/yolov3-custom.cfg', names='data/customdata/custom.names', weights='weights/last.pt', source='/content/gdrive/MyDrive/public/youtube_video', output='youTube_out', img_size=512, conf_thres=0.1, iou_thres=0.6, fourcc='mp4v', half=False, device='', view_img=False, save_txt=False, classes=None, agnostic_nms=False, augment=False)
# Using CUDA device0 _CudaDeviceProperties(name='NVIDIA A100-SXM4-40GB', total_memory=40513MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/801 /content/gdrive/MyDrive/public/youtube_video/image-100.jpg: 320x512 Done. (0.023s)
# ...

# %%
# !python detect.py --source=/content/gdrive/MyDrive/public/validation --conf-thres 0.1 --output validation_out
# Out:
# Namespace(cfg='cfg/yolov3-custom.cfg', names='data/customdata/custom.names', weights='weights/last.pt', source='/content/gdrive/MyDrive/public/validation', output='validation_out', img_size=512, conf_thres=0.1, iou_thres=0.6, fourcc='mp4v', half=False, device='', view_img=False, save_txt=False, classes=None, agnostic_nms=False, augment=False)
# Using CUDA device0 _CudaDeviceProperties(name='NVIDIA A100-SXM4-40GB', total_memory=40513MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/17 /content/gdrive/MyDrive/public/validation/baloo__01.jpg: 384x512 Done. (0.022s)
# ...

# %%
Image(filename='/content/gdrive/MyDrive/public/validation_out/sherkhan_01.jpg', width=200)

# %%
Image(filename='/content/gdrive/MyDrive/public/validation_out/rebecca_01.jpg', width=200)

# %%
Image(filename='/content/gdrive/MyDrive/public/validation_out/kingsLouie_01.jpg', width=200)

# %%
Image(filename='/content/gdrive/MyDrive/public/validation_out/baloo_donkarnage.jpg', width=200)
